# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/Student Attitude and Behavior.csv')

# %%
df.head()
# Out:
#   Certification Course  Gender Department  Height(CM)  Weight(KG)  10th Mark  \
# 0                   No    Male        BCA       100.0        58.0       79.0
# 1                   No  Female        BCA        90.0        40.0       70.0
# 2                  Yes    Male        BCA       159.0        78.0       71.0
# 3                  Yes  Female        BCA       147.0        20.0       70.0
# 4                   No    Male        BCA       170.0        54.0       40.0
#
#    12th Mark  college mark        hobbies daily studing time  \
# 0       64.0          80.0    Video Games      0 - 30 minute
# 1       80.0          70.0         Cinema     30 - 60 minute
# 2       61.0          55.0         Cinema         1 - 2 Hour
# 3       59.0          58.0  Reading books         1 - 2 Hour
# 4       65.0          30.0    Video Games     30 - 60 minute
#
#   prefer to study in  salary expectation Do you like your degree?  \
# ...

# %%
df.shape
# Out:
# (235, 19)

# %%
df.drop('Height(CM)',axis=1,inplace=True)

# %%
df.drop('Weight(KG)',axis=1,inplace=True)

# %%
df.isnull().sum()
# Out:
# Certification Course                                      0
# Gender                                                    0
# Department                                                0
# 10th Mark                                                 0
# 12th Mark                                                 0
# college mark                                              0
# hobbies                                                   0
# daily studing time                                        0
# prefer to study in                                        0
# salary expectation                                        0
# Do you like your degree?                                  0
# willingness to pursue a career based on their degree      0
# social medai & video                                      0
# Travelling Time                                           0
# Stress Level                                              0
# Financial Status                                          0
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#         10th Mark   12th Mark  college mark  salary expectation
# count  235.000000  235.000000    235.000000        2.350000e+02
# mean    76.848511   68.775872     70.660553        3.248168e+04
# std     13.047560   11.018192     15.727446        1.113146e+05
# min      7.400000   45.000000      1.000000        0.000000e+00
# 25%     70.000000   60.000000     60.000000        1.500000e+04
# 50%     80.000000   69.000000     70.000000        2.000000e+04
# 75%     86.250000   76.000000     80.000000        2.500000e+04
# max     98.000000   94.000000    100.000000        1.500000e+06

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#   Certification Course  Gender Department  10th Mark  12th Mark  college mark  \
# 0                   No       1        BCA       79.0       64.0          80.0
# 1                   No       0        BCA       70.0       80.0          70.0
# 2                  Yes       1        BCA       71.0       61.0          55.0
# 3                  Yes       0        BCA       70.0       59.0          58.0
# 4                   No       1        BCA       40.0       65.0          30.0
#
#          hobbies daily studing time prefer to study in  salary expectation  \
# 0    Video Games      0 - 30 minute            Morning               40000
# 1         Cinema     30 - 60 minute            Morning               15000
# 2         Cinema         1 - 2 Hour            Anytime               13000
# 3  Reading books         1 - 2 Hour            Anytime             1500000
# 4    Video Games     30 - 60 minute            Morning               50000
#
#   Do you like your degree?  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    object
#  1   Gender                                                  235 non-null    object
#  2   Department                                              235 non-null    object
#  3   10th Mark                                               235 non-null    float64
#  4   12th Mark                                               235 non-null    float64
#  5   college mark                                            235 non-null    float64
#  6   hobbies                                                 235 non-null    object
#  7   daily studing time                                      235 non-null    object
# ...

# %%
df['Certification Course'] = le.fit_transform(df['Certification Course'])

# %%
df['Department'] = le.fit_transform(df['Department'])

# %%
df['daily studing time'] = le.fit_transform(df['daily studing time'])

# %%
df['hobbies'] = le.fit_transform(df['hobbies'])

# %%
df['prefer to study in'] = le.fit_transform(df['prefer to study in'])

# %%
df['part-time job'] = le.fit_transform(df['part-time job'])

# %%
df['Financial Status'] = le.fit_transform(df['Financial Status'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   Certification Course                                    235 non-null    int64
#  1   Gender                                                  235 non-null    int64
#  2   Department                                              235 non-null    int64
#  3   10th Mark                                               235 non-null    float64
#  4   12th Mark                                               235 non-null    float64
#  5   college mark                                            235 non-null    float64
#  6   hobbies                                                 235 non-null    int64
#  7   daily studing time                                      235 non-null    int64
# ...

# %%
df['social medai & video'] = le.fit_transform(df['social medai & video'])

# %%
df['Travelling Time ']=le.fit_transform(df['Travelling Time '])

# %%
df.columns
# Out:
# Index(['Certification Course', 'Gender', 'Department', '10th Mark',
#        '12th Mark', 'college mark', 'hobbies', 'daily studing time',
#        'prefer to study in', 'salary expectation', 'Do you like your degree?',
#        'willingness to pursue a career based on their degree  ',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status', 'part-time job'],
#       dtype='object')

# %%
df['Stress Level ']=le.fit_transform(df['Stress Level '])

# %%
df['Do you like your degree?']=le.fit_transform(df['Do you like your degree?'])

# %%
df['willingness to pursue a career based on their degree  ']=le.fit_transform(df['willingness to pursue a career based on their degree  '])

# %%
df.head()
# Out:
#    Certification Course  Gender  Department  10th Mark  12th Mark  \
# 0                     0       1           2       79.0       64.0
# 1                     0       0           2       70.0       80.0
# 2                     1       1           2       71.0       61.0
# 3                     1       0           2       70.0       59.0
# 4                     0       1           2       40.0       65.0
#
#    college mark  hobbies  daily studing time  prefer to study in  \
# 0          80.0        3                   0                   1
# 1          70.0        0                   4                   1
# 2          55.0        0                   1                   0
# 3          58.0        1                   1                   0
# 4          30.0        3                   4                   1
#
#    salary expectation  Do you like your degree?  \
# 0               40000                         0
# 1               15000                         1
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f',linewidths=1.5,linecolor='black',square=True,annot_kws={'size':10})
plt.show()

# %%
X=df.drop('Stress Level ',axis=1)

# %%
y=df['Stress Level ']

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model=ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
rank=pd.Series(model.feature_importances_,index=X.columns)

# %%
rank.nlargest(10).plot(kind='barh')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['10th Mark', '12th Mark', 'college mark', 'hobbies',
#        'daily studing time', 'prefer to study in', 'salary expectation',
#        'social medai & video', 'Travelling Time ', 'Stress Level ',
#        'Financial Status'],
#       dtype='object')

# %%
rank.nlargest(18).plot(kind='barh')
# Out:
# <Axes: >

# %%
X=df.drop('Stress Level ',axis=1)

# %%
X
# Out:
#      10th Mark  12th Mark  college mark  hobbies  daily studing time  \
# 0         79.0       64.0          80.0        3                   0
# 1         70.0       80.0          70.0        0                   4
# 2         71.0       61.0          55.0        0                   1
# 3         70.0       59.0          58.0        1                   1
# 4         40.0       65.0          30.0        3                   4
# ..         ...        ...           ...      ...                 ...
# 230       72.0       67.0          65.0        3                   4
# 231       72.0       70.0          76.0        0                   2
# 232       90.0       75.0          70.0        0                   4
# 233       85.0       74.0          75.0        0                   0
# 234       45.0       45.0          50.0        2                   3
#
#      prefer to study in  salary expectation  social medai & video  \
# 0                     1               40000                     3
# ...

# %%
y=df['Stress Level ']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=nb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.6056338028169014

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.43      0.15      0.22        20
#            2       0.67      0.89      0.76        44
#            3       0.17      0.25      0.20         4
#
#     accuracy                           0.61        71
#    macro avg       0.32      0.32      0.30        71
# weighted avg       0.55      0.61      0.55        71

# %%
nb.score(X_train,y_train)
# Out:
# 0.5914634146341463

# %%
param_grid = {
    'var_smoothing': np.logspace(0,-9, num=100),
    'priors': [None]

}

from sklearn.model_selection import GridSearchCV
gs=GridSearchCV(nb,param_grid=param_grid,cv=5,scoring='accuracy',n_jobs=-1)

# %%
gs.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=GaussianNB(), n_jobs=-1,
#              param_grid={'priors': [None],
#                          'var_smoothing': array([1.00000000e+00, 8.11130831e-01, 6.57933225e-01, 5.33669923e-01,
#        4.32876128e-01, 3.51119173e-01, 2.84803587e-01, 2.31012970e-01,
#        1.87381742e-01, 1.51991108e-01, 1.23284674e-01, 1.00000000e-01,
#        8.11130831e-02, 6.57933225e-02, 5.33669923e-02, 4.32876128e-02,
#        3.511191...
#        1.23284674e-07, 1.00000000e-07, 8.11130831e-08, 6.57933225e-08,
#        5.33669923e-08, 4.32876128e-08, 3.51119173e-08, 2.84803587e-08,
#        2.31012970e-08, 1.87381742e-08, 1.51991108e-08, 1.23284674e-08,
#        1.00000000e-08, 8.11130831e-09, 6.57933225e-09, 5.33669923e-09,
#        4.32876128e-09, 3.51119173e-09, 2.84803587e-09, 2.31012970e-09,
#        1.87381742e-09, 1.51991108e-09, 1.23284674e-09, 1.00000000e-09])},
#              scoring='accuracy')

# %%
gs.best_score_
# Out:
# 0.5910984848484848

# %%
gs.best_params_
# Out:
# {'priors': None, 'var_smoothing': 0.43287612810830584}

# %% [markdown]
# Logistic Regression

# %%
X1=df.drop('Stress Level ',axis=1)

# %%
X1
# Out:
#      10th Mark  12th Mark  college mark  hobbies  daily studing time  \
# 0         79.0       64.0          80.0        3                   0
# 1         70.0       80.0          70.0        0                   4
# 2         71.0       61.0          55.0        0                   1
# 3         70.0       59.0          58.0        1                   1
# 4         40.0       65.0          30.0        3                   4
# ..         ...        ...           ...      ...                 ...
# 230       72.0       67.0          65.0        3                   4
# 231       72.0       70.0          76.0        0                   2
# 232       90.0       75.0          70.0        0                   4
# 233       85.0       74.0          75.0        0                   0
# 234       45.0       45.0          50.0        2                   3
#
#      prefer to study in  salary expectation  social medai & video  \
# 0                     1               40000                     3
# ...

# %%
y1=df['Stress Level ']

# %%
from sklearn.model_selection import train_test_split
X1_train,X1_test,y1_train,y1_test=train_test_split(X1,y1,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X1_train,y1_train)
# Out:
# LogisticRegression()

# %%
y_pred1=lr.predict(X1_test)

# %%
lr.score(X1_train,y1_train)
# Out:
# 0.5670731707317073

# %%
print(classification_report(y1_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.00      0.00      0.00        20
#            2       0.62      1.00      0.77        44
#            3       0.00      0.00      0.00         4
#
#     accuracy                           0.62        71
#    macro avg       0.15      0.25      0.19        71
# weighted avg       0.38      0.62      0.47        71
